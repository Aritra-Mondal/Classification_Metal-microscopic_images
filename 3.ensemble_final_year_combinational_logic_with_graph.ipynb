# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print("y_actual=",y_actual)
print("y_res=",y_resnet)
print("y_alex=",y_alexnet)
print("prob1=",prob1)
print("prob2=",prob2)
# Out:
# y_actual= [1, 3, 0, 3, 1, 0, 4, 1, 1, 3, 3, 4, 1, 3, 1, 4, 3, 2, 3, 3, 3, 1, 2, 0, 3, 3, 3, 1, 1, 0, 0, 0, 3, 0, 0, 1, 1, 4, 1, 0, 0, 4, 3, 4, 3, 3, 1, 3, 0, 2, 2, 0, 1, 4, 3, 2, 1, 4, 3, 3, 4, 0, 2, 1, 3, 3, 1, 1, 3, 0, 0, 3, 3, 0, 3, 0, 2, 3, 3, 4, 1, 0, 0, 4, 1, 3, 0, 0, 0, 4, 3, 3, 1, 3, 0, 0, 3, 3, 3, 3, 4, 0, 1, 4, 2, 3, 1, 0, 4, 3, 2, 3, 3, 2, 4, 3, 0, 2, 0, 1, 0, 1, 3, 2, 0, 2, 3, 2, 1, 3, 1, 1, 3, 2, 3, 1, 3, 2, 3, 3, 3, 4, 4, 3, 2, 3, 0, 2, 3, 2, 3, 2, 0, 4, 3, 3, 1, 0, 1, 1, 0, 4, 3, 2, 4, 1, 0, 1, 0, 0, 3, 0, 4, 2, 2, 4, 1, 3, 0, 4, 3, 0, 4, 4, 1, 4, 4, 0, 0, 3, 0, 0, 3, 3, 3, 3, 3, 1, 4, 0, 1, 3, 3, 3, 3, 3, 0, 4, 4, 1, 0, 1, 1, 2, 3, 0, 3, 2, 1, 4, 3]
# ...

# %%
from decimal import *
getcontext().prec = 4

# %%
k=0.975925925925926
Decimal(210)/Decimal(221)
# Out:
# Decimal('0.9502')

# %%
# import pandas as pd

# df1 =pd.read_csv('supportSVM.csv')
# df2 =pd.read_csv('supportRF.csv')
# df3 =pd.read_csv('supportKNN.csv')
# df4 =pd.read_csv('actual1.csv')
# df5 =pd.read_csv('predSVM.csv')
# df6 =pd.read_csv('predKNN.csv')
# df7 =pd.read_csv('predRF.csv')
# df8 =pd.read_csv('predChoquet.csv')
# df9 =pd.read_csv('predSugeno.csv')

# %%
# prob1=df1.values.tolist()
# prob2=df2.values.tolist()
# prob3=df3.values.tolist()
# y_ori=df4.values.tolist()
# y1=df5.values.tolist()
# y2=df6.values.tolist()
# y3=df7.values.tolist()
# y4=df8.values.tolist()
# y5=df9.values.tolist()
# print(len(prob1))
# y_actual=[]
# for i in range(len(y_ori[0])):
#   y_actual.append(y_ori[0][i]-1)

# y_svm=[]
# for i in range(len(y1[0])):
#   y_svm.append(y1[0][i]-1)

# y_knn=[]
# for i in range(len(y2[0])):
#   y_knn.append(y2[0][i]-1)

# y_rf=[]
# for i in range(len(y3[0])):
#   y_rf.append(y3[0][i]-1)

# y_ch=[]
# for i in range(len(y4[0])):
#   y_ch.append(y4[0][i]-1)

# y_sg=[]
# for i in range(len(y5[0])):
#   y_sg.append(y5[0][i]-1)

# print("Actual=",y_actual)
# print("SVM=",y_svm)
# print("KNN=",y_knn)
# print("RF=",y_rf)
# print("Choquet=",y_ch)
# print("Sugeno=",y_sg)
# num_test=221

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
print("Resnet18:")
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
  
 
results = confusion_matrix(y_actual, y_resnet) 
plt.figure(figsize=(10,10))
sns.heatmap(results, annot=True, cmap="YlGnBu",
            xticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"],
            yticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"])
  
print ('Confusion Matrix :')
print(results)
# print("classWise Accuracy:")
# print("class 1:",Decimal(int(results[0][0]))/Decimal(180)*100)
# print("class 2:",Decimal(int(results[1][1]))/Decimal(180)*100)
# print("class 3:",Decimal(int(results[2][2]))/Decimal(180)*100)
print ('Accuracy Score :',Decimal(accuracy_score(y_actual, y_resnet))/Decimal(1)*100 )
print ('Report : ')
print (classification_report(y_actual, y_resnet) )
# Out:
# Resnet18:
# Confusion Matrix :
# [[48  0  0  0  0]
#  [ 0 41  0  1  0]
#  [ 0  0 24  0  1]
#  [ 1  1  0 66  6]
#  [ 0  0  1  4 27]]
# Accuracy Score : 93.21
# Report :
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        48
#            1       0.98      0.98      0.98        42
#            2       0.96      0.96      0.96        25
#            3       0.93      0.89      0.91        74
#            4       0.79      0.84      0.82        32
#
#     accuracy                           0.93       221
#    macro avg       0.93      0.93      0.93       221
# weighted avg       0.93      0.93      0.93       221

# %%
plt.figure(figsize=(10,10))
sns.heatmap(pd.DataFrame(classification_report(y_actual, y_resnet, output_dict=True)).iloc[:-1, :].T , annot=True, cmap="YlGnBu")

# %%
print("Alexnet:")
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
  
 
results = confusion_matrix(y_actual, y_alexnet) 

plt.figure(figsize=(10,10))
sns.heatmap(results, annot=True, cmap="YlGnBu",
            xticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"],
            yticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"])
  
print ('Confusion Matrix :')
print(results)
# print("classWise Accuracy:")
# print("class 1:",Decimal(int(results[0][0]))/Decimal(180)*100)
# print("class 2:",Decimal(int(results[1][1]))/Decimal(180)*100)
# print("class 3:",Decimal(int(results[2][2]))/Decimal(180)*100) 
print ('Accuracy Score :',Decimal(accuracy_score(y_actual, y_alexnet))/Decimal(1) *100)
print ('Report : ')
print (classification_report(y_actual, y_alexnet) )
# Out:
# Alexnet:
# Confusion Matrix :
# [[45  0  3  0  0]
#  [ 1 38  0  2  1]
#  [ 0  0 22  2  1]
#  [ 0  0  2 65  7]
#  [ 0  0  0  1 31]]
# Accuracy Score : 90.95
# Report :
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96        48
#            1       1.00      0.90      0.95        42
#            2       0.81      0.88      0.85        25
#            3       0.93      0.88      0.90        74
#            4       0.78      0.97      0.86        32
#
#     accuracy                           0.91       221
#    macro avg       0.90      0.91      0.90       221
# weighted avg       0.92      0.91      0.91       221

# %%
resnet=0.9321
alexnet=0.9095
t=resnet+alexnet/2

resnet_n=resnet/t
alexnet_n=alexnet/t

print(resnet)
print(alexnet)
print()
print(resnet_n)
print(alexnet_n)
# Out:
# 0.9321
# 0.9095
#
# 0.6720986408047014
# 0.6558027183905974

# %%
y_temp=[]
y_wsum=[]
num_test=221
for i in range(num_test):
  # y_temp.append([(prob1[i][0]*svm_n+prob2[i][0]*knn_n+prob3[i][0]*rf_n)/3,(prob1[i][1]*svm_n+prob2[i][1]*knn_n+prob3[i][1]*rf_n)/3,(prob1[i][2]*svm_n+prob2[i][2]*knn_n+prob3[i][2]*rf_n)/3])
  y_temp.append([(prob1[i][0]*resnet_n+prob2[i][0]*alexnet_n)/2,(prob1[i][1]*resnet_n+prob2[i][1]*alexnet_n)/2,(prob1[i][2]*resnet_n+prob2[i][2]*alexnet_n)/2,(prob1[i][3]*resnet_n+prob2[i][3]*alexnet_n)/2,(prob1[i][4]*resnet_n+prob2[i][4]*alexnet_n)/2])
for i in range(num_test):
  y_wsum.append(y_temp[i].index(max(y_temp[i])))
print(y_temp)
print(y_wsum)

print("Ensemble Weighted Sum Rule:")
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
  
 
results = confusion_matrix(y_actual, y_wsum) 

plt.figure(figsize=(10,10))
sns.heatmap(results, annot=True, cmap="YlGnBu",
            xticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"],
            yticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"])
  
print ('Confusion Matrix :')
print(results) 
# print("classWise Accuracy:")
# print("class 1:",Decimal(int(results[0][0]))/Decimal(180)*100)
# print("class 2:",Decimal(int(results[1][1]))/Decimal(180)*100)
# print("class 3:",Decimal(int(results[2][2]))/Decimal(180)*100)
print ('Accuracy Score :',Decimal(accuracy_score(y_actual, y_wsum))/Decimal(1) *100)
print ('Report : ')
print (classification_report(y_actual, y_wsum) )
# Out:
# [[0.000123012554042864, 0.6630775323189014, 5.863563255192191e-05, 0.0005290515315277053, 0.00016247625232886944], [4.334389020885437e-05, 0.0005625195488290526, 0.0005433176070484674, 0.6354245117047872, 0.027377013505888354], [0.37881138815916615, 0.0021623677035996556, 0.261783871692127, 0.0004016908097701726, 0.020791330562102864], [8.825153452437982e-05, 0.004922713049184606, 0.0002648493262456809, 0.6393861342865503, 0.019288720482251564], [0.0009146229036407935, 0.66205967867276, 1.2999679489335578e-05, 0.0005755479013671268, 0.0003878214346707176], [0.5702957724465054, 0.09021700295769816, 0.0004146272086191019, 0.0014953598917321332, 0.0015279163158431058], [0.00013623635317381864, 0.0003199707018603798, 0.0002712759493240335, 0.05965733544833323, 0.6035658507420687], [0.0012584419150616303, 0.6476953706242097, 0.007593494480493165, 0.005682382545496774, 0.0017209897463837177], [0.00018216989052540877, 0.6619228522663321, 0.00031224573336470816, 0.0013305484879183262, 0.0002
# ...

# %%
y_temp=[]
y_wprod=[]

for i in range(num_test):
  # y_temp.append([(prob1[i][0]**svm*prob2[i][0]**knn*prob3[i][0]**rf)/3,(prob1[i][1]**svm*prob2[i][1]**knn_n*prob3[i][1]**rf_n)/3,(prob1[i][2]**svm_n*prob2[i][2]**knn_n*prob3[i][2]**rf_n)/3])
  y_temp.append([(prob1[i][0]**resnet_n*prob2[i][0]**alexnet_n)/2,(prob1[i][1]**resnet_n*prob2[i][1]**alexnet_n)/2,(prob1[i][2]**resnet_n*prob2[i][2]**alexnet_n)/2,(prob1[i][3]**resnet_n*prob2[i][3]**alexnet_n)/2,(prob1[i][4]**resnet_n*prob2[i][4]**alexnet_n)/2])

for i in range(num_test):
  y_wprod.append(y_temp[i].index(max(y_temp[i])))
print(y_temp)
print(y_wprod)

print("Ensemble Weighted product Rule:")
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
  
 
results = confusion_matrix(y_actual, y_wprod) 

plt.figure(figsize=(10,10))
sns.heatmap(results, annot=True, cmap="YlGnBu",
            xticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"],
            yticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"])
  
print ('Confusion Matrix :')
print(results) 
# print("classWise Accuracy:")
# print("class 1:",Decimal(int(results[0][0]))/Decimal(180)*100)
# print("class 2:",Decimal(int(results[1][1]))/Decimal(180)*100)
# print("class 3:",Decimal(int(results[2][2]))/Decimal(180)*100)
print ('Accuracy Score :',Decimal(accuracy_score(y_actual, y_wprod))/Decimal(1)*100 )
print ('Report : ')
print (classification_report(y_actual, y_wprod) )
# Out:
# [[5.836949847860932e-11, 0.4991264808504125, 8.231343806030801e-11, 5.730665169292193e-07, 2.8076674471744823e-11], [1.1314198533931067e-13, 8.840397323704598e-13, 6.397319752633423e-12, 0.4710611277974461, 4.418000754615873e-07], [0.22881789024148597, 8.40989997600873e-06, 0.13731528225583342, 7.486365627604037e-06, 0.003110525427753091], [6.949350313803149e-09, 1.581784511920476e-06, 3.675974364756551e-08, 0.47513137970830155, 4.002705226551418e-05], [4.650736690182192e-05, 0.4981098686256983, 2.7586822557116434e-07, 3.935993476607547e-05, 1.0110335017759051e-05], [0.4014749636631849, 0.0012073258150763534, 7.932233336540201e-08, 9.51972613850214e-08, 1.3011921890566252e-05], [1.8760670150339364e-08, 7.524524127234394e-11, 2.3368326767003163e-07, 0.002193731464383007, 0.4377719840053974], [1.0866597784175077e-06, 0.48361609174169423, 1.400324064790177e-05, 0.00011122493902827273, 8.627615033469522e-06], [6.894885084959086e-11, 0.49797016110088804, 1.9994718246947644e-11, 1.45503339
# ...

# %%
sum_rule=[]
for i in range(len(prob1)):
  # sum_rule.append([(prob1[i][0]+prob2[i][0]+prob3[i][0])/3,(prob1[i][1]+prob2[i][1]+prob3[i][1])/3,(prob1[i][2]+prob2[i][2]+prob3[i][2])/3])
  sum_rule.append([(prob1[i][0]+prob2[i][0])/2,(prob1[i][1]+prob2[i][1])/2,(prob1[i][2]+prob2[i][2])/2,(prob1[i][3]+prob2[i][3])/2,(prob1[i][4]+prob2[i][4])/2])
print(sum_rule)
# Out:
# [[0.00018302752988005042, 0.9987008571624756, 8.724259961542628e-05, 0.0007871714186364898, 0.00024174465245028004], [6.449037027803389e-05, 0.0008369598072026402, 0.000808389682797305, 0.9575565755367279, 0.04073362436150596], [0.5689250081777573, 0.0032174490911529574, 0.39566707611083984, 0.0005982141428830801, 0.03159220702946186], [0.0001313074732953723, 0.007324394498056108, 0.00039406342137660033, 0.9634508490562439, 0.028699368929210323], [0.0013650569744640961, 0.9971544146537781, 1.9544171664165333e-05, 0.0008705938817001879, 0.0005903773344471119], [0.8606479465961456, 0.13423656221129932, 0.0006169147167689459, 0.002224911522538342, 0.002273664430504141], [0.0002027030868338997, 0.00047607699591236394, 0.0004036291901599043, 0.09094789274968207, 0.9079696834087372], [0.0018724151969990999, 0.9758117198944092, 0.01129825190196243, 0.00845684408704983, 0.0025607684256101493], [0.00027104636058181424, 0.9969828426837921, 0.0004645831942054105, 0.001979692655437404, 0.0003018
# ...

# %%
sum_pred=[]
for i in range(len(prob1)):
  sum_pred.append(sum_rule[i].index(max(sum_rule[i])))
print(len(sum_pred))
# Out:
# 221

# %%
print("Ensemble Sum Rule:")
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
  
 
results = confusion_matrix(y_actual, sum_pred) 
plt.figure(figsize=(10,10))
sns.heatmap(results, annot=True, cmap="YlGnBu",
            xticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"],
            yticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"])
  
print ('Confusion Matrix :')
print(results) 
# print("classWise Accuracy:")
# print("class 1:",Decimal(int(results[0][0]))/Decimal(180)*100)
# print("class 2:",Decimal(int(results[1][1]))/Decimal(180)*100)
# print("class 3:",Decimal(int(results[2][2]))/Decimal(180)*100)
print ('Accuracy Score :',Decimal(accuracy_score(y_actual, sum_pred))/Decimal(1)*100 )
print ('Report : ')
print (classification_report(y_actual, sum_pred) )
# Out:
# Ensemble Sum Rule:
# Confusion Matrix :
# [[48  0  0  0  0]
#  [ 0 41  0  1  0]
#  [ 0  0 22  1  2]
#  [ 0  0  2 66  6]
#  [ 0  0  0  1 31]]
# Accuracy Score : 94.12
# Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        48
#            1       1.00      0.98      0.99        42
#            2       0.92      0.88      0.90        25
#            3       0.96      0.89      0.92        74
#            4       0.79      0.97      0.87        32
#
#     accuracy                           0.94       221
#    macro avg       0.93      0.94      0.94       221
# weighted avg       0.95      0.94      0.94       221

# %%
prod_rule=[]
for i in range(len(prob1)):
  # prod_rule.append([(prob1[i][0]*prob2[i][0]*prob3[i][0])/3,(prob1[i][1]*prob2[i][1]*prob3[i][1])/3,(prob1[i][2]*prob2[i][2]*prob3[i][2])/3])
  prod_rule.append([(prob1[i][0]*prob2[i][0])/2,(prob1[i][1]*prob2[i][1])/2,(prob1[i][2]*prob2[i][2])/2,(prob1[i][3]*prob2[i][3])/2,(prob1[i][4]*prob2[i][4])/2])

# %%
prod_pred=[]
for i in range(len(prob1)):
  prod_pred.append(prod_rule[i].index(max(prod_rule[i])))

# %%
print("Ensemble Product Rule:")

from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
  
 
results = confusion_matrix(y_actual, prod_pred) 

plt.figure(figsize=(10,10))
sns.heatmap(results, annot=True, cmap="YlGnBu",
            xticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"],
            yticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"])
  
print ('Confusion Matrix :')
print(results) 
# print("classWise Accuracy:")
# print("class 1:",Decimal(int(results[0][0]))/Decimal(180)*100)
# print("class 2:",Decimal(int(results[1][1]))/Decimal(180)*100)
# print("class 3:",Decimal(int(results[2][2]))/Decimal(180)*100)
print ('Accuracy Score :',Decimal(accuracy_score(y_actual, prod_pred))/Decimal(1)*100 )
print ('Report : ')
print (classification_report(y_actual, prod_pred) )
# Out:
# Ensemble Product Rule:
# Confusion Matrix :
# [[48  0  0  0  0]
#  [ 0 41  0  1  0]
#  [ 0  0 23  0  2]
#  [ 0  0  2 65  7]
#  [ 0  0  0  1 31]]
# Accuracy Score : 94.12
# Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        48
#            1       1.00      0.98      0.99        42
#            2       0.92      0.92      0.92        25
#            3       0.97      0.88      0.92        74
#            4       0.78      0.97      0.86        32
#
#     accuracy                           0.94       221
#    macro avg       0.93      0.95      0.94       221
# weighted avg       0.95      0.94      0.94       221

# %%
num_test=221
import numpy as np
num_class=5
classifier1_rank=[]
classifier2_rank=[]
# classifier3_rank=[]

for i in prob1:
  classifier1_rank.append(list((np.argsort(i)+1)[::-1]))

for i in prob2:
  classifier2_rank.append(list((np.argsort(i)+1)[::-1]))

# for i in prob3:
#   classifier3_rank.append(list((np.argsort(i)+1)[::-1]))

print("classifier 1 rank:",classifier1_rank)
print("classifier 2 rank:",classifier2_rank)
# print("classifier 3 rank:",classifier3_rank)
final_rank=[]
# for i in range(num_test):
#   final_rank.append([(num_class-classifier1_rank[i].index(1)+1)+(num_class-classifier2_rank[i].index(1)+1)+(num_class-classifier3_rank[i].index(1)+1),(num_class-classifier1_rank[i].index(2)+1)+(num_class-classifier2_rank[i].index(2)+1)+(num_class-classifier3_rank[i].index(2)+1)])
# print(final_rank)
for i in range(num_test):
  class_1=(2*num_class-2-(classifier1_rank[i].index(1)+classifier2_rank[i].index(1)))
  class_2=(2*num_class-2-(classifier1_rank[i].index(2)+classifier2_rank[i].index(2)))
  class_3=(2*num_class-2-(classifier1_rank[i].index(3)+classifier2_rank[i].index(3)))
  class_4=(2*num_class-2-(classifier1_rank[i].index(4)+classifier2_rank[i].index(4)))
  class_5=(2*num_class-2-(classifier1_rank[i].index(5)+classifier2_rank[i].index(5)))
  final_rank.append([class_1,class_2,class_3,class_4,class_5])
print("final rank :",final_rank)
y_borda=[]
# for i in final_rank:
#   if i[0]>i[1]:
#     y_borda.append(int(0))
#   else:
#     y_borda.append(int(1))
for i in final_rank:
  y_borda.append(i.index(max(i)))
print("actual label:",y_actual)
print("y_borda label :",y_borda)
print("Ensemble Borda Count Rule:")

from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
  
 
results = confusion_matrix(y_actual, y_borda) 

plt.figure(figsize=(10,10))
sns.heatmap(results, annot=True, cmap="YlGnBu",
            xticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"],
            yticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"])
  
print ('Confusion Matrix :')
print(results) 
# print("classWise Accuracy:")
# print("class 1:",Decimal(int(results[0][0]))/Decimal(180)*100)
# print("class 2:",Decimal(int(results[1][1]))/Decimal(180)*100)
# print("class 3:",Decimal(int(results[2][2]))/Decimal(180)*100)
print ('Accuracy Score :',Decimal(accuracy_score(y_actual, y_borda))/Decimal(1)*100 )
print ('Report : ')
print (classification_report(y_actual, y_borda) )
# Out:
# classifier 1 rank: [[2, 4, 5, 1, 3], [4, 5, 2, 3, 1], [1, 3, 5, 2, 4], [4, 5, 2, 3, 1], [2, 1, 4, 5, 3], [1, 2, 5, 4, 3], [5, 4, 2, 3, 1], [2, 3, 4, 5, 1], [2, 4, 3, 5, 1], [4, 5, 3, 2, 1], [4, 5, 2, 3, 1], [5, 4, 2, 3, 1], [2, 1, 5, 4, 3], [4, 5, 2, 3, 1], [2, 1, 5, 4, 3], [4, 5, 3, 2, 1], [4, 5, 3, 2, 1], [3, 4, 1, 2, 5], [4, 5, 2, 1, 3], [4, 5, 3, 2, 1], [4, 2, 3, 1, 5], [2, 4, 5, 3, 1], [3, 5, 1, 2, 4], [1, 2, 5, 3, 4], [4, 5, 3, 2, 1], [4, 5, 3, 1, 2], [4, 5, 2, 1, 3], [2, 5, 4, 3, 1], [2, 4, 1, 5, 3], [1, 5, 3, 4, 2], [1, 3, 5, 2, 4], [1, 5, 3, 4, 2], [4, 2, 5, 3, 1], [1, 5, 2, 4, 3], [1, 5, 3, 4, 2], [2, 5, 4, 1, 3], [2, 4, 5, 1, 3], [5, 4, 1, 2, 3], [2, 4, 1, 5, 3], [1, 5, 2, 3, 4], [1, 3, 5, 4, 2], [5, 4, 3, 2, 1], [4, 5, 3, 2, 1], [5, 1, 3, 4, 2], [4, 5, 2, 3, 1], [4, 5, 2, 1, 3], [2, 4, 5, 1, 3], [4, 5, 2, 3, 1], [1, 2, 3, 5, 4], [3, 1, 5, 2, 4], [3, 5, 2, 4, 1], [1, 2, 3, 5, 4], [2, 4, 5, 1, 3], [5, 1, 4, 3, 2], [4, 5, 3, 1, 2], [5, 4, 2, 3, 1], [2, 4, 1, 3, 5], [5, 1, 4,
# ...

# %%
from statistics import mode
y_mod=[]

for i in range(num_test):
  try:
    y_mod.append(mode([y_resnet[i],y_alexnet[i]]))
  except:
    y_mod.append(y_resnet[i])



from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
  
 
results = confusion_matrix(y_actual, y_mod) 

plt.figure(figsize=(10,10))
sns.heatmap(results, annot=True, cmap="YlGnBu",
            xticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"],
            yticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"])
print("Ensemble Majority Voting Rule:")  
print ('Confusion Matrix :')
print(results) 
# print("classWise Accuracy:")
# print("class 1:",Decimal(int(results[0][0]))/Decimal(180)*100)
# print("class 2:",Decimal(int(results[1][1]))/Decimal(180)*100)
# print("class 3:",Decimal(int(results[2][2]))/Decimal(180)*100)
print ('Accuracy Score :',Decimal(accuracy_score(y_actual, y_mod))/Decimal(1) *100)
print ('Report : ')
print (classification_report(y_actual, y_mod) )
# Out:
# Ensemble Majority Voting Rule:
# Confusion Matrix :
# [[48  0  0  0  0]
#  [ 0 41  0  1  0]
#  [ 0  0 24  0  1]
#  [ 1  1  0 66  6]
#  [ 0  0  1  4 27]]
# Accuracy Score : 93.21
# Report :
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        48
#            1       0.98      0.98      0.98        42
#            2       0.96      0.96      0.96        25
#            3       0.93      0.89      0.91        74
#            4       0.79      0.84      0.82        32
#
#     accuracy                           0.93       221
#    macro avg       0.93      0.93      0.93       221
# weighted avg       0.93      0.93      0.93       221

# %%
from statistics import median
y_temp=[]
y_med=[]


for i in range(num_test):
  y_temp.append([median([prob1[i][0],prob2[i][0]]),median([prob1[i][1],prob2[i][1]]),median([prob1[i][2],prob2[i][2]]),median([prob1[i][3],prob2[i][3]]),median([prob1[i][4],prob2[i][4]])])
  # y_temp.append([median([prob1[i][0],prob2[i][0],prob3[i][0]]),median([prob1[i][1],prob2[i][1],prob3[i][1]]),median([prob1[i][2],prob2[i][2],prob3[i][2]])])
print(y_temp)
for i in range(num_test):
  y_med.append(y_temp[i].index(max(y_temp[i])))
print(y_med)

from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
  
 
results = confusion_matrix(y_actual, y_med) 

plt.figure(figsize=(10,10))
sns.heatmap(results, annot=True, cmap="YlGnBu",
            xticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"],
            yticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"])
print("Ensemble Median Rule:")
print ('Confusion Matrix :')
print(results) 
# print("classWise Accuracy:")
# print("class 1:",Decimal(int(results[0][0]))/Decimal(180)*100)
# print("class 2:",Decimal(int(results[1][1]))/Decimal(180)*100)
# print("class 3:",Decimal(int(results[2][2]))/Decimal(180)*100)
print ('Accuracy Score :',Decimal(accuracy_score(y_actual, y_med))/Decimal(1)*100 )
print ('Report : ')
print (classification_report(y_actual, y_med) )
# Out:
# [[0.00018302752988005042, 0.9987008571624756, 8.724259961542628e-05, 0.0007871714186364898, 0.00024174465245028004], [6.449037027803389e-05, 0.0008369598072026402, 0.000808389682797305, 0.9575565755367279, 0.04073362436150596], [0.5689250081777573, 0.0032174490911529574, 0.39566707611083984, 0.0005982141428830801, 0.03159220702946186], [0.0001313074732953723, 0.007324394498056108, 0.00039406342137660033, 0.9634508490562439, 0.028699368929210323], [0.0013650569744640961, 0.9971544146537781, 1.9544171664165333e-05, 0.0008705938817001879, 0.0005903773344471119], [0.8606479465961456, 0.13423656221129932, 0.0006169147167689459, 0.002224911522538342, 0.002273664430504141], [0.0002027030868338997, 0.00047607699591236394, 0.0004036291901599043, 0.09094789274968207, 0.9079696834087372], [0.0018724151969990999, 0.9758117198944092, 0.01129825190196243, 0.00845684408704983, 0.0025607684256101493], [0.00027104636058181424, 0.9969828426837921, 0.0004645831942054105, 0.001979692655437404, 0.0003018
# ...

# %%
y_temp=[]
y_min=[]

for i in range(num_test):
  y_temp.append([min(prob1[i][0],prob2[i][0]),min(prob1[i][1],prob2[i][1]),min(prob1[i][2],prob2[i][2]),min(prob1[i][3],prob2[i][3]),min(prob1[i][4],prob2[i][4])])
  # y_temp.append([min(prob1[i][0],prob2[i][0],prob3[i][0]),min(prob1[i][1],prob2[i][1],prob3[i][1]),min(prob1[i][2],prob2[i][2],prob3[i][2])])
print(y_temp)
for i in range(num_test):
  y_min.append(y_temp[i].index(max(y_temp[i])))
print(y_min)

from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
  
 
results = confusion_matrix(y_actual, y_min) 

plt.figure(figsize=(10,10))
sns.heatmap(results, annot=True, cmap="YlGnBu",
            xticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"],
            yticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"])
print("Ensemble Min Rule:")
print ('Confusion Matrix :')
print(results) 
# print("classWise Accuracy:")
# print("class 1:",Decimal(int(results[0][0]))/Decimal(180)*100)
# print("class 2:",Decimal(int(results[1][1]))/Decimal(180)*100)
# print("class 3:",Decimal(int(results[2][2]))/Decimal(180)*100)
print ('Accuracy Score :',Decimal(accuracy_score(y_actual, y_min))/Decimal(1) *100)
print ('Report : ')
print (classification_report(y_actual, y_min) )
# Out:
# [[2.3760271094380725e-12, 0.9974023103713989, 8.575747750816376e-12, 6.515762720482599e-07, 5.852612773755983e-13], [5.056881456919147e-16, 8.40367592052797e-16, 1.7806377439156737e-14, 0.9151131510734558, 7.674199054008568e-09], [0.43720588088035583, 9.260896149498876e-06, 0.2828103303909302, 4.517726119956933e-05, 0.008968539535999298], [4.8852637490881534e-09, 3.1144924150794395e-07, 2.0085071383846298e-08, 0.9269126653671265, 1.0599832421576139e-05], [0.00034733026404865086, 0.9969491362571716, 1.6682912246324122e-05, 0.0005657939473167062, 7.98204418970272e-05], [0.7217154502868652, 0.00039372436003759503, 4.0993533900746115e-08, 1.4540644244220857e-08, 2.5829473088379018e-05], [1.4233519252115912e-08, 1.3138767417791852e-12, 3.290113284037943e-07, 0.0016519655473530293, 0.8197559118270874], [7.110813839972252e-07, 0.9518199563026428, 5.555535153689561e-06, 0.00017806551477406174, 1.2178737961221486e-05], [2.0483116071334795e-12, 0.9939656853675842, 1.785600747122862e-13, 3.1297
# ...

# %%
y_temp=[]
y_max=[]

for i in range(num_test):
  y_temp.append([max(prob1[i][0],prob2[i][0]),max(prob1[i][1],prob2[i][1]),max(prob1[i][2],prob2[i][2]),max(prob1[i][3],prob2[i][3]),max(prob1[i][4],prob2[i][4])])
  # y_temp.append([max(prob1[i][0],prob2[i][0],prob3[i][0]),max(prob1[i][1],prob2[i][1],prob3[i][1]),max(prob1[i][2],prob2[i][2],prob3[i][2])])
print(y_temp)
for i in range(num_test):
  y_max.append(y_temp[i].index(max(y_temp[i])))
print(y_max)

from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
  
 
results = confusion_matrix(y_actual, y_max) 
plt.figure(figsize=(10,10))
sns.heatmap(results, annot=True, cmap="YlGnBu",
            xticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"],
            yticklabels=["Martensite", "Network", "Pearlite", "Spheroidite", "Spheroidite-widmanstatten"])
print("Ensemble Max Rule:")
print ('Confusion Matrix :')
print(results) 
# print("classWise Accuracy:")
# print("class 1:",Decimal(int(results[0][0]))/Decimal(180)*100)
# print("class 2:",Decimal(int(results[1][1]))/Decimal(180)*100)
# print("class 3:",Decimal(int(results[2][2]))/Decimal(180)*100)
print ('Accuracy Score :',Decimal(accuracy_score(y_actual, y_max))/Decimal(1)*100 )
print ('Report : ')
print (classification_report(y_actual, y_max) )
# Out:
# [[0.00036605505738407373, 0.9999994039535522, 0.00017448519065510482, 0.0015736912610009313, 0.0004834893043152988], [0.00012898074055556208, 0.00167391961440444, 0.0016167793655768037, 1.0, 0.08146724104881287], [0.7006441354751587, 0.006425637286156416, 0.5085238218307495, 0.0011512510245665908, 0.05421587452292442], [0.0002626100613269955, 0.014648477546870708, 0.0007881067576818168, 0.9999890327453613, 0.05738813802599907], [0.0023827836848795414, 0.9973596930503845, 2.2405431082006544e-05, 0.0011753938160836697, 0.0011009342269971967], [0.999580442905426, 0.26807940006256104, 0.0012337884400039911, 0.00444980850443244, 0.004521499387919903], [0.0004053919401485473, 0.0009521539905108511, 0.0008069293689914048, 0.1802438199520111, 0.996183454990387], [0.0037441193126142025, 0.9998034834861755, 0.02259094826877117, 0.0167356226593256, 0.005109358113259077], [0.0005420927191153169, 1.0, 0.0009291663882322609, 0.003959354013204575, 0.0006037070997990668], [0.006345749367028475, 0.06
# ...

# %%
print("Y_actual=",y_actual)
print("Y_sum_pred=",sum_pred)
print("Y_prod_pred=",prod_pred)
# Out:
# Y_actual= [1, 3, 0, 3, 1, 0, 4, 1, 1, 3, 3, 4, 1, 3, 1, 4, 3, 2, 3, 3, 3, 1, 2, 0, 3, 3, 3, 1, 1, 0, 0, 0, 3, 0, 0, 1, 1, 4, 1, 0, 0, 4, 3, 4, 3, 3, 1, 3, 0, 2, 2, 0, 1, 4, 3, 2, 1, 4, 3, 3, 4, 0, 2, 1, 3, 3, 1, 1, 3, 0, 0, 3, 3, 0, 3, 0, 2, 3, 3, 4, 1, 0, 0, 4, 1, 3, 0, 0, 0, 4, 3, 3, 1, 3, 0, 0, 3, 3, 3, 3, 4, 0, 1, 4, 2, 3, 1, 0, 4, 3, 2, 3, 3, 2, 4, 3, 0, 2, 0, 1, 0, 1, 3, 2, 0, 2, 3, 2, 1, 3, 1, 1, 3, 2, 3, 1, 3, 2, 3, 3, 3, 4, 4, 3, 2, 3, 0, 2, 3, 2, 3, 2, 0, 4, 3, 3, 1, 0, 1, 1, 0, 4, 3, 2, 4, 1, 0, 1, 0, 0, 3, 0, 4, 2, 2, 4, 1, 3, 0, 4, 3, 0, 4, 4, 1, 4, 4, 0, 0, 3, 0, 0, 3, 3, 3, 3, 3, 1, 4, 0, 1, 3, 3, 3, 3, 3, 0, 4, 4, 1, 0, 1, 1, 2, 3, 0, 3, 2, 1, 4, 3]
# ...
